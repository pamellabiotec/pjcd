# %% [markdown]
# # Visualização de Dados - Oficina Aula 4.2
#
# Olá estudante!
#
# Nesta oficina você irá analisar distribuições conjuntas de um conjunto de dados sobre carros. Esse conjunto de dados contém informações sobre: consumo de galão de combustível por milha (miles per galon, mpg), número de cilindros, cilindrada, cavalos de potência, peso, aceleração, ano do modelo, país de origem e nome do carro. Esse conjunto de dados chama-se “mpg” e é bastante famoso em estatística, sendo disponibilizado diretamente pela biblioteca seaborn sem a necessidade de baixar os dados para a sua máquina. Crie um Jupyter Notebook para responder às questões.
#
# 1. Importe as bibliotecas pandas, matplotlib e seaborn e use a palavra mágica inline para exibir as visualizações no notebook. Carregue os dados em um DataFrame. Os dados podem ser carregados pelo seaborn utilizando a função load_dataset(‘mpg’).
# 2. Crie uma visualização que mostre a distribuição conjunta de todas as variáveis quantitativas, diferenciando pelo país de origem (‘origin’). Quais variáveis possuem uma maior correlação?
# 3. Sobre a visualização da questão 2, é possível distinguir o país de origem a partir da distribuição de uma variável? E de uma distribuição conjunta?
# 4. Escolha uma distribuição conjunta em que as variáveis estejam fortemente correlacionadas e crie um gráfico que permita analisar a distribuição conjunta, a reta de regressão e as distribuições marginais.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")
print ("Setup completo")
# Out:
# Setup completo

# %%
# Questão 1
df = sns.load_dataset("mpg")
df.tail()
# Out:
#       mpg  cylinders  displacement  ...  model_year  origin             name
# 393  27.0          4         140.0  ...          82     usa  ford mustang gl
# 394  44.0          4          97.0  ...          82  europe        vw pickup
# 395  32.0          4         135.0  ...          82     usa    dodge rampage
# 396  28.0          4         120.0  ...          82     usa      ford ranger
# 397  31.0          4         119.0  ...          82     usa       chevy s-10
#
# [5 rows x 9 columns]

# %%
# Questão 2
sns.pairplot(df, hue='origin')

# Resposta: Infelizmente, no meu computador, gerou um erro ao usar o parâmetro hue para diferenciar pelo país de origem (‘origin’) na distribuição
# conjunta de dados. Logo, não possibilitou fazer análise da correlação entre as variáveis. Em hipotése, considerei fazer a
# distribuição conjunta de algumas variáveis quantitativas ("mpg", "cylinders", "acceleration"). E mesmo assim, houve erro na
# visualização de dados ao utilizar a função pairplot() nesse dataset 'mpg'. Ao tentar via Google Colab, a função pairplot contendo o parâmentro hue 
# para diferenciar pelo país de origem ('origin') teve um visualização de dados ok. Assim, posso analisar a visualização de dados, as variáveis que tem mais 
# correlação: consumo de galão de combustível por milha (miles per galon, mpg) teve baixa correlação negativa com cilindrada("displacement"), cavalos de potência
# ("horsepower"), peso("weight"), sem correlação com  aceleração("acceleration") e com ano do modelo ("model_year"); número de cilindros ("cylinders") apresentou 
# sem correlação com todas as variáveis; cilindrada("displacement") apresentou baixa correlação negativa com "mpg" e aceleração("acceleration"), mas, teve uma 
# alta correlação positiva com cavalos de potência("horsepower") e peso("weight"), e sem correlação com ano do modelo ("model_year"); cavalos de potência 
# ("horsepower") apresentou baixa correlação negativa com "mpg" e aceleração("acceleration"), também apresentou alta correlação positiva com cilindrada 
# ("displacement") e peso("weight"), sem correlção com número de cilindros ("cylinders") e o ano do modelo ("model_year"); peso("weight") teve baixa correlação
# negativa com "mpg", também apresentou alta correlação positiva com cilindrada("displacement") e  cavalos de potência("horsepower"), e sem correlção com 
# aceleração("acceleration") e ano do modelo ("model_year"); aceleração("acceleration") não teve correlação com "mpg", peso("weight") e ano do modelo ("model_year"), 
# apresentou uma baixa correlação negativa com cilindrada("displacement") e cavalos de potência("horsepower"); ano do modelo ("model_year") apresentou sem correlação
# com todas as variáveis. Logo, as variáveis que apresentam maior correlação são cilindrada("displacement"), cavalos de potência("horsepower") e peso("weight").

# %% [markdown]
# ### Questão 3
# Resposta: Sim, em relação a **questão 2**, é possível distinguir o país de origem a partir da distribuição de uma variável como também na distribuição conjunta.

# %%
# Questão 4 - reta de regressão na distribuição conjunta.
sns.pairplot(df, kind='reg')

# %%
# Questão 4 - distribuição marginal e bivariada
sns.jointplot(x="displacement", y="horsepower", kind = 'kde', data=df)

# %% [markdown]
# Desenvolvido por: **Pâmella Araújo Balcaçar**, Rondonópolis-MT, 02/02/2021.
