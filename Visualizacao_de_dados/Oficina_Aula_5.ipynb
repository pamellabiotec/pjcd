# %% [markdown]
# # Visualização de dados
#
# ## Oficina Aula 5
#
# Durante os estudos nesse curso, você pôde compreender como dashboards interativos são úteis para analisar conjuntos de dados, permitindo uma exploração dinâmica em diferentes níveis de detalhes. Além disso, foi possível criar visualizações e um dashboard, utilizando o Kibana. Agora, chegou a hora de exercitar o que você aprendeu! Se ainda não tiver feito isso, será preciso ter o Elasticsearch e o Kibana instalados na sua máquina e carregar os dados de amostra Sample flight data disponibilizados pelo Kibana em Sample data. Sobre esses dados, responda às seguintes perguntas:
#
# 1. Abra o [Flights] Global Flight Dashboard. Explorando os dados com esse dashboard, responda às seguintes perguntas relativas ao último ano:
#  >a. Qual o total de voos nesse período?
#
#  >b. Qual a quantidade de voos atrasados?
#
#  >c. Qual o intervalo de tempo de atraso é mais frequente? E o menos frequente?
#
#  >d. Qual o total de voos que tiveram como país de origem a Austrália (AU)?
#
# 2. Crie um dashboard que permita visualizar as seguintes informações e responda às perguntas relativas ao último ano:
#
#  >a. A quantidade de voos que partiram de cada país (OriginCountry): qual país teve a menor quantidade de voos?
#
#  >b. A média de minutos de atraso em voos (FlightDelayMin) por companhia de voo (Carrier): qual companhia, em média, teve mais minutos de atraso?
#
#  >c. A proporção dos diferentes tipos de clima do local de partida (OriginWeather) e, destes, a proporção dos voos cancelados (Cancelled): qual o clima teve a maior proporção geral de voos cancelados?

# %% [markdown]
# # 1 - Explorando os dados
#
# a. Qual o total de voos nesse período?
# **Resposta: 333 voos no último ano**.
#
# b. Qual a quantidade de voos atrasados?
# **Resposta: 75 voos atrasados**.
#
# c. Qual o intervalo de tempo de atraso é mais frequente? E o menos frequente?
# **Resposta: O intervalo de tempo de atraso mais frequente é de 30 minutos, 60 minutos e 210 minutos. E o menos frequente é de 120 minutos e também de 360 minutos**.
#
# d. Qual o total de voos que tiveram como país de origem a Austrália (AU)?
# **Resposta: 12 voos**.

# %% [markdown]
# # 2 - Crie um dashboard
#
# ![image.png](attachment:image.png)
#
# a. A quantidade de voos que partiram de cada país (OriginCountry): qual país teve a menor quantidade de voos?
# **Resposta: O país que teve menor quantidade de voos foi Canadá (CA)**.
#
# b. A média de minutos de atraso em voos (FlightDelayMin) por companhia de voo (Carrier): qual companhia, em média, teve mais minutos de atraso?
# **Resposta: JetBeats teve mais minutos de atraso, em média, (26.59%)**.
#
# c. A proporção dos diferentes tipos de clima do local de partida (OriginWeather) e, destes, a proporção dos voos cancelados (Cancelled): qual o clima teve a maior proporção geral de voos cancelados?
# **Resposta: Hail teve a maior proporção geral de voos cancelados 75**.

# %% [markdown]
# Desenvolvido por: **Pâmella Araújo Balcaçar**, Rondonópolis-MT, 12/02/2021
